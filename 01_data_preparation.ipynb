# %%
import importlib
import src.step1_etl_bronze
importlib.reload(src.step1_etl_bronze)
from src.step1_etl_bronze import run_bronze_extraction

DB_URI = 'postgresql://postgres:postgres@localhost:5432/shardbox_development'
ANCHOR = "2026-05-06"
run_bronze_extraction(db_uri=DB_URI, anchor_date=ANCHOR)
# Out:
# 2026-07-12 14:59:24,058 - INFO - Conectando a la BD y generando 30 snapshots hasta 2026-05-06...
# 2026-07-12 14:59:24,156 - INFO - Snapshot [2018-05-28] extraído: 545 nodos, 545 aristas.
# 2026-07-12 14:59:24,301 - INFO - Snapshot [2018-09-05] extraído: 604 nodos, 639 aristas.
# 2026-07-12 14:59:24,463 - INFO - Snapshot [2018-12-14] extraído: 660 nodos, 705 aristas.
# 2026-07-12 14:59:24,622 - INFO - Snapshot [2019-03-24] extraído: 698 nodos, 778 aristas.
# 2026-07-12 14:59:24,782 - INFO - Snapshot [2019-07-02] extraído: 735 nodos, 826 aristas.
# 2026-07-12 14:59:24,942 - INFO - Snapshot [2019-10-10] extraído: 778 nodos, 870 aristas.
# 2026-07-12 14:59:25,099 - INFO - Snapshot [2020-01-18] extraído: 822 nodos, 923 aristas.
# 2026-07-12 14:59:25,260 - INFO - Snapshot [2020-04-27] extraído: 886 nodos, 1007 aristas.
# 2026-07-12 14:59:25,415 - INFO - Snapshot [2020-08-05] extraído: 944 nodos, 1158 aristas.
# ...

# %%
import importlib
import src.step2_etl_silver
importlib.reload(src.step2_etl_silver)
from src.step2_etl_silver import run_silver_processing

raw_dir: str = "data/01_raw" 
processed_dir: str = "data/02_processed"
run_silver_processing(raw_dir, processed_dir)
# Out:
# 2026-07-12 14:59:48,618 - INFO - ⚙️ Iniciando el procesamiento por lotes de la red (Capa Silver)...
# 2026-07-12 14:59:48,622 - INFO - Omitiendo Año 2018 Día 148 (Ya procesado)
# 2026-07-12 14:59:48,622 - INFO - Omitiendo Año 2018 Día 248 (Ya procesado)
# 2026-07-12 14:59:48,623 - INFO - Omitiendo Año 2018 Día 348 (Ya procesado)
# 2026-07-12 14:59:48,623 - INFO - Omitiendo Año 2019 Día 183 (Ya procesado)
# 2026-07-12 14:59:48,623 - INFO - Omitiendo Año 2019 Día 283 (Ya procesado)
# 2026-07-12 14:59:48,624 - INFO - Omitiendo Año 2019 Día 83 (Ya procesado)
# 2026-07-12 14:59:48,624 - INFO - Omitiendo Año 2020 Día 118 (Ya procesado)
# 2026-07-12 14:59:48,624 - INFO - Omitiendo Año 2020 Día 18 (Ya procesado)
# 2026-07-12 14:59:48,625 - INFO - Omitiendo Año 2020 Día 218 (Ya procesado)
# 2026-07-12 14:59:48,625 - INFO - Omitiendo Año 2020 Día 318 (Ya procesado)
# 2026-07-12 14:59:48,626 - INFO - Omitiendo Año 2021 Día 152 (Ya procesado)
# ...

# %%
import importlib
import src.step3_etl_gold
importlib.reload(src.step3_etl_gold)
from src.step3_etl_gold import run_gold_layer_prep

processed_dir: str = "data/02_processed"
gold_dir: str = "data/03_gold"
run_gold_layer_prep()
# Out:
# 2026-07-12 15:00:15,477 - INFO - Consolidando el Master Dataset (Capa Gold)...
# 2026-07-12 15:00:15,542 - INFO - ✅ Master dataset guardado. Total de registros históricos: 27782
# 2026-07-12 15:00:15,542 - INFO - Indexando snapshots disponibles para materializar 30 cortes...
# 2026-07-12 15:00:15,550 - INFO - ✅ 2018-05-28: Materializado (usando datos del 2018-05-28)
# 2026-07-12 15:00:15,554 - INFO - ✅ 2018-09-05: Materializado (usando datos del 2018-09-05)
# 2026-07-12 15:00:15,559 - INFO - ✅ 2018-12-14: Materializado (usando datos del 2018-12-14)
# 2026-07-12 15:00:15,564 - INFO - ✅ 2019-03-24: Materializado (usando datos del 2019-03-24)
# 2026-07-12 15:00:15,575 - INFO - ✅ 2019-07-02: Materializado (usando datos del 2019-07-02)
# 2026-07-12 15:00:15,587 - INFO - ✅ 2019-10-10: Materializado (usando datos del 2019-10-10)
# 2026-07-12 15:00:15,595 - INFO - ✅ 2020-01-18: Materializado (usando datos del 2020-01-18)
# ...

# %%
import importlib
import src.step4_taxonomy
importlib.reload(src.step4_taxonomy)
from src.step4_taxonomy import process_taxonomy_layer

RAW = "data/01_raw"
SILVER = "data/02_processed"

process_taxonomy_layer(RAW, SILVER)
